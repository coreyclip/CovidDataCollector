# %%
import pandas as pd
import pygsheets
import os

# %%
df = pd.read_csv('data/scraped_data/08-27-2020/LA_County_Covid19_CSA_case_death_table.csv').drop('Unnamed: 0',1).set_index('City/Community')
tdf = pd.read_csv('data/scraped_data/08-27-2020/LA_County_Covid19_CSA_testing_table.csv').drop('Unnamed: 0',1)

# %%
def set_index_to_geo(df):
    if 'geo_merge' in df.columns:
        df.set_index('geo_merge', inplace=True)
        df.index.rename('City/Community', inplace=True)
    elif 'City/Community' in df.columns:
        df.set_index('City/Community', inplace=True)
    else:
        raise Exception(f"missing geo column: {df.info()}")
    return df

# %%
cities = df.index
dates = os.listdir('data/scraped_data')
columns = list(df.columns.append(tdf.columns))
columns.remove("timestamp")
case_columns = df.columns
testing_columns = tdf.columns
print(cities)
print(dates)
print(columns)
cdf = df.join(tdf)
# Out:
# Index(['City of Agoura Hills', 'City of Alhambra', 'City of Arcadia',
#        'City of Artesia', 'City of Avalon', 'City of Azusa',
#        'City of Baldwin Park', 'City of Bell', 'City of Bell Gardens',
#        'City of Bellflower',
#        ...
#        'Unincorporated - Westhills', 'Unincorporated - White Fence Farms',
#        'Unincorporated - Whittier', 'Unincorporated - Willowbrook',
#        'Unincorporated - Wiseburn', 'Unincorporated - East Lancaster',
#        'Unincorporated - Harbor Gateway', 'Unincorporated - La Habra Heights',
#        'Unincorporated - Placerita Canyon',
#        'Unincorporated - Whittier Narrows'],
#       dtype='object', name='City/Community', length=332)
# ['08-29-2020', '08-22-2020', '08-19-2020', '08-27-2020']
# ['Cases', 'Case Rate', 'Adjusted Case Rate', 'Deaths', 'Death Rate', 'Adjusted Death Rate', 'Population', 'geo_merge', 'persons_tested_final', 'testing_rate_final', 'adj_testing_rate_final', 'persons_tested_pos_final', 'pos_testing_rate_final', 'adj_pos_testing_rate_final', 'population']

# %%
dfs = {}
for d in os.listdir('data/scraped_data'):
    if os.path.isdir(os.path.join('data/scraped_data', d)):
        date = d
        dfs[date] = {}
        
        case_death_path = os.path.join(os.path.join('data/scraped_data', d),'LA_County_Covid19_CSA_case_death_table.csv')
        if os.path.exists(case_death_path):
            dfs[date]['case_death'] = set_index_to_geo(pd.read_csv(case_death_path).drop('Unnamed: 0',1))
        else:
            dfs[date]['case_death'] = pd.DataFrame(index=[cities], data=[], columns=case_columns)
            
        testing_path = os.path.join(os.path.join('data/scraped_data', d),'LA_County_Covid19_CSA_testing_table.csv')
        if os.path.exists(testing_path):
            dfs[date]['testing'] = set_index_to_geo(pd.read_csv(testing_path).drop('Unnamed: 0',1))
        else:
            dfs[date]['testing'] = pd.DataFrame(index=[cities], data=[], columns=testing_columns)

# %%
tdf = dfs["08-27-2020"]['testing']
tdf
# Out:
#                                     persons_tested_final  testing_rate_final  \
# City/Community
# City of Agoura Hills                                3874             18551.0
# City of Alhambra                                   16357             18861.0
# City of Arcadia                                     7665             13272.0
# City of Artesia                                     4012             23888.0
# City of Avalon                                        75              1938.0
# ...                                                  ...                 ...
# Unincorporated - White Fence Farms                   449             12191.0
# Unincorporated - Whittier                            569             15037.0
# Unincorporated - Whittier Narrows                      7             58333.0
# Unincorporated - Willowbrook                        8597             24624.0
# Unincorporated - Wiseburn                           1223             20292.0
#
#                                     adj_testing_rate_final  \
# City/Community
# City of Agoura Hills                                 17883
# City of Alhambra                                     18362
# City of Arcadia                                      13133
# City of Artesia                                      21555
# City of Avalon                                        1896
# ...                                                    ...
# Unincorporated - White Fence Farms                   12931
# Unincorporated - Whittier                            14239
# Unincorporated - Whittier Narrows                    22207
# Unincorporated - Willowbrook                         25028
# Unincorporated - Wiseburn                            20086
#
#                                     persons_tested_pos_final  \
# City/Community
# City of Agoura Hills                                     136
# City of Alhambra                                        1116
# City of Arcadia                                          424
# City of Artesia                                          288
# City of Avalon                                             5
# ...                                                      ...
# Unincorporated - White Fence Farms                        43
# Unincorporated - Whittier                                 57
# Unincorporated - Whittier Narrows                          0
# Unincorporated - Willowbrook                            1396
# Unincorporated - Wiseburn                                107
#
#                                     pos_testing_rate_final  \
# City/Community
# City of Agoura Hills                                   651
# City of Alhambra                                      1287
# City of Arcadia                                        734
# City of Artesia                                       1715
# City of Avalon                                         129
# ...                                                    ...
# Unincorporated - White Fence Farms                    1168
# Unincorporated - Whittier                             1506
# Unincorporated - Whittier Narrows                        0
# Unincorporated - Willowbrook                          3999
# Unincorporated - Wiseburn                             1775
#
#                                     adj_pos_testing_rate_final  population
# City/Community
# City of Agoura Hills                                       626     20883.0
# City of Alhambra                                          1292     86724.0
# City of Arcadia                                            710     57754.0
# City of Artesia                                           1674     16795.0
# City of Avalon                                             151      3869.0
# ...                                                        ...         ...
# Unincorporated - White Fence Farms                        1248      3683.0
# Unincorporated - Whittier                                 1446      3784.0
# Unincorporated - Whittier Narrows                            0         NaN
# Unincorporated - Willowbrook                              4041     34913.0
# Unincorporated - Wiseburn                                 1677      6027.0
#
# [331 rows x 7 columns]

# %%
df = dfs["08-27-2020"]['case_death']
df
# Out:
#                                    Cases  Case Rate  Adjusted Case Rate  \
# City/Community
# City of Agoura Hills                 142        680                 663
# City of Alhambra                    1122       1294                1290
# City of Arcadia                      436        755                 726
# City of Artesia                      294       1751                1700
# City of Avalon                         5        129                 151
# ...                                  ...        ...                 ...
# Unincorporated - East Lancaster        0          0                   0
# Unincorporated - Harbor Gateway        0          0                   0
# Unincorporated - La Habra Heights      0          0                   0
# Unincorporated - Placerita Canyon      0          0                   0
# Unincorporated - Whittier Narrows      0          0                   0
#
#                                    Deaths  Death Rate  Adjusted Death Rate  \
# City/Community
# City of Agoura Hills                    2          10                   10
# City of Alhambra                       23          27                   18
# City of Arcadia                        30          52                   33
# City of Artesia                         4          24                   15
# City of Avalon                          0           0                    0
# ...                                   ...         ...                  ...
# Unincorporated - East Lancaster         0           0                    0
# Unincorporated - Harbor Gateway         0           0                    0
# Unincorporated - La Habra Heights       0           0                    0
# Unincorporated - Placerita Canyon       0           0                    0
# Unincorporated - Whittier Narrows       0           0                    0
#
#                                    Population                   timestamp
# City/Community
# City of Agoura Hills                    20883  2020-08-27 22:56:30.555436
# City of Alhambra                        86724  2020-08-27 22:56:30.555436
# City of Arcadia                         57754  2020-08-27 22:56:30.555436
# City of Artesia                         16795  2020-08-27 22:56:30.555436
# City of Avalon                           3869  2020-08-27 22:56:30.555436
# ...                                       ...                         ...
# Unincorporated - East Lancaster           114  2020-08-27 22:56:30.555436
# Unincorporated - Harbor Gateway             1  2020-08-27 22:56:30.555436
# Unincorporated - La Habra Heights         676  2020-08-27 22:56:30.555436
# Unincorporated - Placerita Canyon         460  2020-08-27 22:56:30.555436
# Unincorporated - Whittier Narrows          12  2020-08-27 22:56:30.555436
#
# [332 rows x 8 columns]

# %%
cities_dfs = {}
for city in cities:
#     print(city)
    city_df = pd.DataFrame(index=dates, data=[], columns=columns)
    for date in dates:
        if 'case_death' in dfs[date].keys():
            if city in dfs[date]['case_death'].index:
                cdf = dfs[date]['case_death'].loc[city]
            else:
                cdf = pd.DataFrame(index=[city], data=[], columns=case_columns)
        else:
            cdf = pd.DataFrame(index=[city], data=[], columns=case_columns)
        if 'testing' in dfs[date].keys():
            if city in dfs[date]['testing'].index:
                tdf = dfs[date]['testing'].loc[city]
            else:
                tdf = pd.DataFrame(index=[city], data=[], columns=testing_columns)
        else:
            tdf = pd.DataFrame(index=[city], data=[], columns=testing_columns)
        row = cdf.append(tdf).to_dict()
        city_df.loc[date] = row
    cities_dfs[city] = city_df
#     print(city_df)

# %%
for key, df in cities_dfs.items():
    city = key.replace('/', '-')
    path = os.path.join('data/parsed_data', f"{city}.csv")
    df.to_csv(path)

# %% [markdown]
# ## Upload to google sheets

# %%
gc = pygsheets.authorize(service_file='metal-density-185407-d3e92887de1c.json')
# gc.create('LA County Covid-19 Community Level Data')
sh = gc.open('LA County Covid-19 Community Level Data')

# %%
help(gc)
# Out:
# Help on Client in module pygsheets.client object:
#
# class Client(builtins.object)
#  |  Client(credentials, retries=3, http=None, check=True, seconds_per_quota=100)
#  |
#  |  Create or access Google spreadsheets.
#  |
#  |  Exposes members to create new spreadsheets or open existing ones. Use `authorize` to instantiate an instance of this
#  |  class.
#  |
#  |  >>> import pygsheets
#  |  >>> c = pygsheets.authorize()
#  |
#  |  The sheet API service object is stored in the sheet property and the drive API service object in the drive property.
#  |
#  |  >>> c.sheet.get('<SPREADSHEET ID>')
#  |  >>> c.drive.delete('<FILE ID>')
#  |
#  |  :param credentials:             The credentials object returned by google-auth or google-auth-oauthlib.
#  |  :param retries:                 (Optional) Number of times to retry a connection before raising a TimeOut error.
#  |                                  Default: 3
#  |  :param http:                    The underlying HTTP object to use to make requests. If not specified, a
#  |                                  :class:`httplib2.Http` instance will be constructed.
#  |  :param check:                   Check for quota error and apply rate limiting.
#  |  :param seconds_per_quota:       Default value is 100 seconds
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, credentials, retries=3, http=None, check=True, seconds_per_quota=100)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  create(self, title, template=None, folder=None, **kwargs)
#  |      Create a new spreadsheet.
#  |
#  |      The title will always be set to the given value (even overwriting the templates title). The template
#  |      can either be a `spreadsheet resource <https://developers.google.com/sheets/api/reference/rest/v4/spreadsheets#resource-spreadsheet>`_
#  |      or an instance of :class:`~pygsheets.Spreadsheet`. In both cases undefined values will be ignored.
#  |
#  |      :param title:       Title of the new spreadsheet.
#  |      :param template:    A template to create the new spreadsheet from.
#  |      :param folder:      The Id of the folder this sheet will be stored in.
#  |      :param kwargs:      Standard parameters (see reference for details).
#  |      :return: :class:`~pygsheets.Spreadsheet`
#  |
#  |  get_range(self, spreadsheet_id, value_range, major_dimension='ROWS', value_render_option=<ValueRenderOption.FORMATTED_VALUE: 'FORMATTED_VALUE'>, date_time_render_option=<DateTimeRenderOption.SERIAL_NUMBER: 'SERIAL_NUMBER'>)
#  |      Returns a range of values from a spreadsheet. The caller must specify the spreadsheet ID and a range.
#  |
#  |      Reference: `request <https://developers.google.com/sheets/api/reference/rest/v4/spreadsheets.values/get>`__
#  |
#  |      :param spreadsheet_id:              The ID of the spreadsheet to retrieve data from.
#  |      :param value_range:                 The A1 notation of the values to retrieve.
#  |      :param major_dimension:             The major dimension that results should use.
#  |                                          For example, if the spreadsheet data is: A1=1,B1=2,A2=3,B2=4, then
#  |                                          requesting range=A1:B2,majorDimension=ROWS will return [[1,2],[3,4]],
#  |                                          whereas requesting range=A1:B2,majorDimension=COLUMNS will return
#  |                                          [[1,3],[2,4]].
#  |      :param value_render_option:         How values should be represented in the output. The default
#  |                                          render option is `ValueRenderOption.FORMATTED_VALUE`.
#  |      :param date_time_render_option:     How dates, times, and durations should be represented in the output.
#  |                                          This is ignored if `valueRenderOption` is `FORMATTED_VALUE`. The default
#  |                                          dateTime render option is [`DateTimeRenderOption.SERIAL_NUMBER`].
#  |      :return:                            An array of arrays with the values fetched. Returns an empty array if no
#  |                                          values were fetched. Values are dynamically typed as int, float or string.
#  |
#  |  open(self, title)
#  |      Open a spreadsheet by title.
#  |
#  |      In a case where there are several sheets with the same title, the first one found is returned.
#  |
#  |      >>> import pygsheets
#  |      >>> c = pygsheets.authorize()
#  |      >>> c.open('TestSheet')
#  |
#  |      :param title:                           A title of a spreadsheet.
#  |
#  |      :returns:                               :class:`~pygsheets.Spreadsheet`
#  |      :raises pygsheets.SpreadsheetNotFound:  No spreadsheet with the given title was found.
#  |
#  |  open_all(self, query='')
#  |      Opens all available spreadsheets.
#  |
#  |      Result can be filtered when specifying the query parameter. On the details on how to form the query:
#  |
#  |      `Reference <https://developers.google.com/drive/v3/web/search-parameters>`_
#  |
#  |      :param query:   (Optional) Can be used to filter the returned metadata.
#  |      :returns:       A list of :class:`~pygsheets.Spreadsheet`.
#  |
#  |  open_as_json(self, key)
#  |      Return a json representation of the spreadsheet.
#  |
#  |      See `Reference <https://developers.google.com/sheets/api/reference/rest/v4/spreadsheets#Spreadsheet>`__ for details.
#  |
#  |  open_by_key(self, key)
#  |      Open a spreadsheet by key.
#  |
#  |      >>> import pygsheets
#  |      >>> c = pygsheets.authorize()
#  |      >>> c.open_by_key('0BmgG6nO_6dprdS1MN3d3MkdPa142WFRrdnRRUWl1UFE')
#  |
#  |      :param key:                             The key of a spreadsheet. (can be found in the sheet URL)
#  |      :returns:                               :class:`~pygsheets.Spreadsheet`
#  |      :raises pygsheets.SpreadsheetNotFound:  The given spreadsheet ID was not found.
#  |
#  |  open_by_url(self, url)
#  |      Open a spreadsheet by URL.
#  |
#  |      >>> import pygsheets
#  |      >>> c = pygsheets.authorize()
#  |      >>> c.open_by_url('https://docs.google.com/spreadsheet/ccc?key=0Bm...FE&hl')
#  |
#  |      :param url:                             URL of a spreadsheet as it appears in a browser.
#  |      :returns:                               :class:`~pygsheets.Spreadsheet`
#  |      :raises pygsheets.SpreadsheetNotFound:  No spreadsheet was found with the given URL.
#  |
#  |  spreadsheet_ids(self, query=None)
#  |      Get a list of all spreadsheet ids present in the Google Drive or TeamDrive accessed.
#  |
#  |  spreadsheet_titles(self, query=None)
#  |      Get a list of all spreadsheet titles present in the Google Drive or TeamDrive accessed.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  teamDriveId
#  |      Enable team drive support
#  |
#  |      Deprecated: use client.drive.enable_team_drive(team_drive_id=?)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  spreadsheet_cls = <class 'pygsheets.spreadsheet.Spreadsheet'>
#  |      A class for a spreadsheet object.

# %%
gc.spreadsheet_ids()
# Out:
# ['1xuTNgF4_3rddeHrYq4gaF05_VQxg285rrtoAu2Nw2Ds',
#  '1LGpiFbaNQ-PkWwxLqz4oImkBnFqj1wN68bRex5JHu_4',
#  '12OKmV4hm4_taX3--IAGkWMIyVnVsuPaxMoC6Qdxwu9A']

# %%
zorgi_wants = [
"City of Industry",
"Los Angeles - Wholesale District",
"City of Vernon",
"Los Angeles - Central",
"Los Angeles - South Park",
"Los Angeles - Florence-Firestone",
"Los Angeles - Little Armenia",
"Los Angeles - Boyle Heights",
"City of Maywood",
"East LA",
"West LA",
"City of Vernon"
"Los Angeles - Florence-Firestone",
"City of Huntington Park",
"City of Irwindale",
"Los Angeles - Westlake",
"Los Angeles - Downtown",
"Unincorporated - Athens Village",
"City of Lynwood"
]

for city, i in zip(zorgi_wants, range(0, len(zorgi_wants))):
    try:
        sh.add_worksheet(city)
    except Exception as e:
        print(str(e))
    if city in cities:
        try:
            assert sh[i].title == city
            sh[i].set_dataframe(cities_dfs[city], (1,1))
        except:
            print(f"{i} {city} {sh[i].title}")
# Out:
# 0 City of Industry City of Agoura Hills
# 1 Los Angeles - Wholesale District City of Alhambra
# 2 City of Vernon City of Arcadia
# 3 Los Angeles - Central City of Artesia
# 4 Los Angeles - South Park City of Avalon
# 5 Los Angeles - Florence-Firestone City of Azusa
# 6 Los Angeles - Little Armenia City of Baldwin Park
# 7 Los Angeles - Boyle Heights City of Bell
# 8 City of Maywood City of Bell Gardens
# 12 City of Huntington Park City of Burbank
# 13 City of Irwindale City of Calabasas
# 14 Los Angeles - Westlake City of Carson
# 15 Los Angeles - Downtown City of Cerritos
# 16 Unincorporated - Athens Village City of Claremont
# 17 City of Lynwood City of Commerce

# %%
gc.link()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-a433d8fb4e48> in <module>
# ----> 1 gc.link()
#
# AttributeError: 'Client' object has no attribute 'link'
